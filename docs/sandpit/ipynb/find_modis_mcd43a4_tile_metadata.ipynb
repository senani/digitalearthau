# %% [markdown]
# # Find_Modis_Mcd43A4_Tile_Metadata
#
# Authors: Claire Krause, Sivaprasad Arapaut.
# Last edited: April 28, 2018
#
# This notebook demonstrates how to find the definition, metadata and measurements about the datasets held within the AGDC. This code is applicable to any product in the datacube, by changing just one line as given below.
#
# >dataset = dc.index.products.get_by_name('**modis_mcd43a4_tile**')

# %% [markdown]
# ## Step-by-step instructions
# Let us go through the process step by step.
#
# ### 1. Import modules and libraries
# The main module we use here is the **datacube**. The **pandas** is a data re-formatting module for convenience.
#
# The **function print_it()**, is to print out the data in an even more human readable format than **pandas** does, or when the latter is unable to re-format the data.

# %%
import datacube
import pandas
def print_it(key,item):
    tt = str(type(item))
    if ('dict' in tt):
        print("{}:".format(key.title()))
        for key in item:
            print_it(key.title(),item[key])
    else:
        print("    {}: {}\n".format(key.title(),item))

# %% [markdown]
# ***Modules and Classes explained***
#
# **datacube:** This is the main module, the only one we use in this demo, and contains several classes that are used in extracting the data. We use only one class, **Datacube**, from this module. To see the full list of classes in this module, use the `print(dir(datacube))` statement.
#
# How every class in Datacube works is beyond the scope of this document. See [Datacube Class](https://datacube-core.readthedocs.io/en/stable/dev/api/api.html#datacube-class) for details. You might also want to look at [this page](https://softwareengineering.stackexchange.com/questions/329348/classes-vs-modules-in-python) to learn the difference between a module and class.
#
# > Class: **Datacube**
#
# > Methods: **list_products**, **list_measurements**
#
# > Usage: dc = datacube.Datacube(app='Some descriptive name')
#
# In the above call, the class 'Datacube' is called with one param, **app**, which is a user-defined alphanumeric name to identify this application. The application name is used to track down problems with database queries, so it is strongly advised to use it. It is mandatory if an index is not supplied, as in the above call, but if an index is given the 'app='is ignored.
#
# We use a number of classes and methods from the datacube module as shown below.
#
# - Module **datacube** -> class '**Datacube**' -> (class '**index**' -> class '**products**' -> method '**get_by_name**', class '**list_products**' and class '**list_measurements**')
#
# The above will list the different products and their data as shown in the code blocks given below. They let one find out the available list of products and measurements and, then, find their corresponding data.
#
# **pandas** is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. It is used here to re-format the data into more human readable format.

# %%
dc = datacube.Datacube(app='dc-metadata')

# %% [markdown]
# The above statement creates a **datacube** object named **dc** which is the class **Datacube**. We will call other classes and methods from it later. The 'app=dc-metadata' is probably not fully correct, as we are going to look at more than metadata. Still, it is a name to identify this application. Errors in execution, if any, will be logged under that name. As explained above, it is optional.
#
# The list of available methods in **dc** are given below, and the ones we use in this doc are marked in bold.
#
# > ['**__init__**', 'close', 'create_storage', 'find_datasets', 'find_datasets_lazy', 'group_datasets', '**index**', '**list_measurements**', '**list_products**', 'load', 'load_data', 'measurement_data', 'product_data', 'product_observations', 'product_sources']
#
# - **__init__**([index, config, app, env, validate_connection]):   *Create the interface for the query and storage.* We have already called this method when creating the object. There will be no error even if do not provide any of the params.
#
# - **index**: This is the class that returns the dataset for your specified product.
#
# - **list_products**(show_archived=False, with_pandas=True): *List products in the datacube.* We will call this in the next block of code to get a list of all products. The 'with_pandas=True' means the data will appear in a nice table format. If you want it in raw format, then pass the param as e.g. '*dc.list_products(with_pandas=False)*'. Then you can write your own functions to format it in any way you like, get subsets of data, etc.
#
# - **list_measurements**(show_archived=False, with_pandas=True): *List measurements for each product.* We will call this method in a code block below to get the measurements for a defined product.
#
# Parameters for the above two methods:
#
#    - show_archived - – If set as True, include products that have been archived.
#    - with_pandas – If True (default), returns the list as a Pandas DataFrame, otherwise as a dictionary.
#
# Return type:	`pandas.DataFrame or list(dict)`
#
# **pandas.DataFrame**: [Pandas](https://pandas.pydata.org/pandas-docs/stable/index.html) is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. 'DataFrame' is a [pandas class object](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) that converts a dictionary into human readable, table format with row and column headings. By default, the two methods we use return the data in this format.

# %%
def custom_list(items):
    n = 0
    print('Name | Description | Product_type | Platform | CRS | Resolution | Spatial_dimensions\n\
------------------------------------------------------------------------------------')
    for i in items:
        n += 1
        try:
            print ("{}. {}  |  {}  |  {}  |  {}  |  {}  |  {} | {} | {}\n".format(n,i['id'],i['name'],i['description'],i['product_type'],i['platform'],i['crs'],i['resolution'],i['spatial_dimensions']))
        except:
            print ("{}. ERROR: id {} has one or more fields with a NaN\n".format(n,i['id']))
            pass
dc.list_products()  # List the products in a table format
#custom_list(dc.list_products(with_pandas=False)) # List selected columns alone from the table.
# Out:
#                             name  \
# id
# 36            bom_rainfall_grids
# 32                      dsm1sv10
# 53                     gamma_ray
# 63            high_tide_comp_20p
# 64          high_tide_comp_count
# 67                       item_v2
# 68                  item_v2_conf
# 65             low_tide_comp_20p
# 66           low_tide_comp_count
# 69                 ls5_fc_albers
# 42        ls5_fc_albers_archived
# 2               ls5_level1_scene
# 6                ls5_nbar_albers
# 3                 ls5_nbar_scene
# 26              ls5_nbart_albers
# 4                ls5_nbart_scene
# 41               ls5_ndvi_albers
# 23                 ls5_pq_albers
# 5                   ls5_pq_scene
# 1   ls5_satellite_telemetry_data
# 70                 ls7_fc_albers
# 44        ls7_fc_albers_archived
# 72         ls7_fc_albers_staging
# 9               ls7_level1_scene
# 21               ls7_nbar_albers
# 10                ls7_nbar_scene
# 29              ls7_nbart_albers
# 11               ls7_nbart_scene
# 45               ls7_ndvi_albers
# 22                 ls7_pq_albers
# 12                  ls7_pq_scene
# 8   ls7_satellite_telemetry_data
# 71                 ls8_fc_albers
# 47        ls8_fc_albers_archived
# 40          ls8_level1_oli_scene
# 14              ls8_level1_scene
# 19               ls8_nbar_albers
# 60           ls8_nbar_oli_albers
# 57            ls8_nbar_oli_scene
# 15                ls8_nbar_scene
# 28              ls8_nbart_albers
# 61          ls8_nbart_oli_albers
# 58           ls8_nbart_oli_scene
# 16               ls8_nbart_scene
# 55               ls8_ndvi_albers
# 20                 ls8_pq_albers
# 59              ls8_pq_oli_scene
# 17                  ls8_pq_scene
# 13  ls8_satellite_telemetry_data
# 49            modis_mcd43a1_tile
# 50            modis_mcd43a2_tile
# 51            modis_mcd43a3_tile
# 52            modis_mcd43a4_tile
# 56                srtm_dem1sv1_0
# 46                   wofs_albers
# 62         wofs_modified_albers2
#
#                                           description  \
# id
# 36  Interpolated Rain Gauge Precipitation 1-Day Au...
# 32                               DSM 1sec Version 1.0
# 53  The 2015 radiometric or gamma-ray grid of Aust...
# 63  High Tide 20 percentage composites for entire ...
# 64                High Tide 20 percentage pixel count
# 67                           Intertidal Extents Model
# 68                    Average ndwi Standard Deviation
# 65  Low Tide 20 percentage composites for entire c...
# 66                 Low Tide 20 percentage pixel count
# 69  Landsat 5 Fractional Cover 25 metre, 100km til...
# 42  Landsat 5 Fractional Cover 25 metre, 100km til...
# 2       Landsat 5 Level 1 At-sensor Radiance 25 metre
# 6   Landsat 5 Surface Reflectance NBAR 25 metre, 1...
# 3                             Landsat 5 NBAR 25 metre
# 26  Landsat 5 Surface Reflectance NBART 25 metre, ...
# 4                            Landsat 5 NBART 25 metre
# 41  Landsat 5 Normalised Difference Vegetation Ind...
# 23  Landsat 5 Pixel Quality 25 metre, 100km tile, ...
# 5                               Landsat 5 PQ 25 metre
# 1                  Landsat 5 Satellite Telemetry Data
# 70  Landsat 7 Fractional Cover 25 metre, 100km til...
# 44  Landsat 7 Fractional Cover 25 metre, 100km til...
# 72  Landsat 7 Fractional Cover 25 metre, 100km til...
# 9       Landsat 7 Level 1 At-sensor Radiance 25 metre
# 21  Landsat 7 Surface Reflectance NBAR 25 metre, 1...
# 10                            Landsat 7 NBAR 25 metre
# 29  Landsat 7 Surface Reflectance NBART 25 metre, ...
# 11                           Landsat 7 NBART 25 metre
# 45  Landsat 7 Normalised Difference Vegetation Ind...
# 22  Landsat 7 Pixel Quality 25 metre, 100km tile, ...
# 12                              Landsat 7 PQ 25 metre
# 8                  Landsat 7 Satellite Telemetry Data
# 71  Landsat 8 Fractional Cover 25 metre, 100km til...
# 47  Landsat 8 Fractional Cover 25 metre, 100km til...
# 40  Landsat 8 OLI Level 1 At-sensor Radiance 25 metre
# 14  Landsat 8 Level 1 OLI-TIRS At-sensor Radiance ...
# 19  Landsat 8 Surface Reflectance NBAR 25 metre, 1...
# 60  Landsat 8 Surface Reflectance NBAR 25 metre, 1...
# 57                        Landsat 8 OLI NBAR 25 metre
# 15                            Landsat 8 NBAR 25 metre
# 28  Landsat 8 Surface Relfectance NBART 25 metre, ...
# 61  Landsat 8 Surface Relfectance NBART 25 metre, ...
# 58                       Landsat 8 OLI NBART 25 metre
# 16                           Landsat 8 NBART 25 metre
# 55  Landsat 8 Normalised Difference Vegetation Ind...
# 20  Landsat 8 Pixel Quality 25 metre, 100km tile, ...
# 59                          Landsat 8 OLI PQ 25 metre
# 17                              Landsat 8 PQ 25 metre
# 13                 Landsat 8 Satellite Telemetry Data
# 49             MODIS 500 metre MCD43A1 Collection 006
# 50             MODIS 500 metre MCD43A2 Collection 006
# 51             MODIS 500 metre MCD43A3 Collection 006
# 52             MODIS 500 metre MCD43A4 Collection 006
# 56                               DEM 1sec Version 1.0
# 46  Historic Flood Mapping Water Observations from...
# 62  Historic Flood Mapping Water Observations from...
#
#                 product_type  gqa_abs_iterative_mean_xy  gqa_cep90  \
# id
# 36                  rainfall                        NaN        NaN
# 32                       DEM                        NaN        NaN
# 53                 gamma_ray                        NaN        NaN
# 63           tidal_composite                        NaN        NaN
# 64           tidal_composite                        NaN        NaN
# 67                      ITEM                        NaN        NaN
# 68                      ITEM                        NaN        NaN
# 65           tidal_composite                        NaN        NaN
# 66           tidal_composite                        NaN        NaN
# 69          fractional_cover                        NaN        NaN
# 42          fractional_cover                        NaN        NaN
# 2                     level1                        NaN        NaN
# 6                       nbar                        NaN        NaN
# 3                       nbar                        NaN        NaN
# 26                     nbart                        NaN        NaN
# 4                      nbart                        NaN        NaN
# 41                      ndvi                        NaN        NaN
# 23                       pqa                        NaN        NaN
# 5                        pqa                        NaN        NaN
# 1   satellite_telemetry_data                        NaN        NaN
# 70          fractional_cover                        NaN        NaN
# 44          fractional_cover                        NaN        NaN
# 72          fractional_cover                        NaN        NaN
# 9                     level1                        NaN        NaN
# 21                      nbar                        NaN        NaN
# 10                      nbar                        NaN        NaN
# 29                     nbart                        NaN        NaN
# 11                     nbart                        NaN        NaN
# 45                      ndvi                        NaN        NaN
# 22                       pqa                        NaN        NaN
# 12                       pqa                        NaN        NaN
# 8   satellite_telemetry_data                        NaN        NaN
# 71          fractional_cover                        NaN        NaN
# 47          fractional_cover                        NaN        NaN
# 40                    level1                        NaN        NaN
# 14                    level1                        NaN        NaN
# 19                      nbar                        NaN        NaN
# 60                      nbar                        NaN        NaN
# 57                      nbar                        NaN        NaN
# 15                      nbar                        NaN        NaN
# 28                     nbart                        NaN        NaN
# 61                     nbart                        NaN        NaN
# 58                     nbart                        NaN        NaN
# 16                     nbart                        NaN        NaN
# 55                      ndvi                        NaN        NaN
# 20                       pqa                        NaN        NaN
# 59                       pqa                        NaN        NaN
# 17                       pqa                        NaN        NaN
# 13  satellite_telemetry_data                        NaN        NaN
# 49                   MCD43A1                        NaN        NaN
# 50                   MCD43A2                        NaN        NaN
# 51                   MCD43A3                        NaN        NaN
# 52                   MCD43A4                        NaN        NaN
# 56                       DEM                        NaN        NaN
# 46                      wofs                        NaN        NaN
# 62                      wofs                        NaN        NaN
#
#                    platform  gqa_iterative_stddev_xy  gqa_iterative_mean_xy  \
# id
# 36                      BoM                      NaN                    NaN
# 32                     SRTM                      NaN                    NaN
# 53                 aircraft                      NaN                    NaN
# 63                     None                      NaN                    NaN
# 64                     None                      NaN                    NaN
# 67                     None                      NaN                    NaN
# 68                     None                      NaN                    NaN
# 65                     None                      NaN                    NaN
# 66                     None                      NaN                    NaN
# 69                LANDSAT_5                      NaN                    NaN
# 42                LANDSAT_5                      NaN                    NaN
# 2                 LANDSAT_5                      NaN                    NaN
# 6                 LANDSAT_5                      NaN                    NaN
# 3                 LANDSAT_5                      NaN                    NaN
# 26                LANDSAT_5                      NaN                    NaN
# 4                 LANDSAT_5                      NaN                    NaN
# 41                LANDSAT_5                      NaN                    NaN
# 23                LANDSAT_5                      NaN                    NaN
# 5                 LANDSAT_5                      NaN                    NaN
# 1                 LANDSAT_5                      NaN                    NaN
# 70                LANDSAT_7                      NaN                    NaN
# 44                LANDSAT_7                      NaN                    NaN
# 72                LANDSAT_7                      NaN                    NaN
# 9                 LANDSAT_7                      NaN                    NaN
# 21                LANDSAT_7                      NaN                    NaN
# 10                LANDSAT_7                      NaN                    NaN
# 29                LANDSAT_7                      NaN                    NaN
# 11                LANDSAT_7                      NaN                    NaN
# 45                LANDSAT_7                      NaN                    NaN
# 22                LANDSAT_7                      NaN                    NaN
# 12                LANDSAT_7                      NaN                    NaN
# 8                 LANDSAT_7                      NaN                    NaN
# 71                LANDSAT_8                      NaN                    NaN
# 47                LANDSAT_8                      NaN                    NaN
# 40                LANDSAT_8                      NaN                    NaN
# 14                LANDSAT_8                      NaN                    NaN
# 19                LANDSAT_8                      NaN                    NaN
# 60                LANDSAT_8                      NaN                    NaN
# 57                LANDSAT_8                      NaN                    NaN
# 15                LANDSAT_8                      NaN                    NaN
# 28                LANDSAT_8                      NaN                    NaN
# 61                LANDSAT_8                      NaN                    NaN
# 58                LANDSAT_8                      NaN                    NaN
# 16                LANDSAT_8                      NaN                    NaN
# 55                LANDSAT_8                      NaN                    NaN
# 20                LANDSAT_8                      NaN                    NaN
# 59                LANDSAT_8                      NaN                    NaN
# 17                LANDSAT_8                      NaN                    NaN
# 13                LANDSAT_8                      NaN                    NaN
# 49               AQUA_TERRA                      NaN                    NaN
# 50               AQUA_TERRA                      NaN                    NaN
# 51               AQUA_TERRA                      NaN                    NaN
# 52               AQUA_TERRA                      NaN                    NaN
# 56  Space Shuttle Endeavour                      NaN                    NaN
# 46                     None                      NaN                    NaN
# 62                     None                      NaN                    NaN
#
#     time  gqa_mean_xy          ...                        instrument  \
# id                             ...
# 36  None          NaN          ...                        rain gauge
# 32  None          NaN          ...                               SIR
# 53  None          NaN          ...            gamma_ray spectrometer
# 63  None          NaN          ...                              None
# 64  None          NaN          ...                              None
# 67  None          NaN          ...                              None
# 68  None          NaN          ...                              None
# 65  None          NaN          ...                              None
# 66  None          NaN          ...                              None
# 69  None          NaN          ...                                TM
# 42  None          NaN          ...                                TM
# 2   None          NaN          ...                                TM
# 6   None          NaN          ...                                TM
# 3   None          NaN          ...                                TM
# 26  None          NaN          ...                                TM
# 4   None          NaN          ...                                TM
# 41  None          NaN          ...                                TM
# 23  None          NaN          ...                                TM
# 5   None          NaN          ...                                TM
# 1   None          NaN          ...                                TM
# 70  None          NaN          ...                               ETM
# 44  None          NaN          ...                               ETM
# 72  None          NaN          ...                               ETM
# 9   None          NaN          ...                               ETM
# 21  None          NaN          ...                               ETM
# 10  None          NaN          ...                               ETM
# 29  None          NaN          ...                               ETM
# 11  None          NaN          ...                               ETM
# 45  None          NaN          ...                               ETM
# 22  None          NaN          ...                               ETM
# 12  None          NaN          ...                               ETM
# 8   None          NaN          ...                               ETM
# 71  None          NaN          ...                          OLI_TIRS
# 47  None          NaN          ...                          OLI_TIRS
# 40  None          NaN          ...                               OLI
# 14  None          NaN          ...                          OLI_TIRS
# 19  None          NaN          ...                          OLI_TIRS
# 60  None          NaN          ...                               OLI
# 57  None          NaN          ...                               OLI
# 15  None          NaN          ...                          OLI_TIRS
# 28  None          NaN          ...                          OLI_TIRS
# 61  None          NaN          ...                               OLI
# 58  None          NaN          ...                               OLI
# 52            NaN       NaN    NaN                NaN  NaN
# 56            NaN       NaN    NaN                NaN  NaN
# 46            NaN       NaN    NaN                NaN  NaN
# 62            NaN       NaN    NaN                NaN  NaN
#
#                                                   crs  \
# id
# 36                                          EPSG:4326
# 32                                          EPSG:4326
# 53  GEOGCS["GEOCENTRIC DATUM of AUSTRALIA",DATUM["...
# 63                                          EPSG:3577
# 64                                          EPSG:3577
# 67                                          EPSG:3577
# 68                                          EPSG:3577
# 65                                          EPSG:3577
# 66                                          EPSG:3577
# 69                                          EPSG:3577
# 42                                          EPSG:3577
# 2                                                 NaN
# 6                                           EPSG:3577
# 3                                                 NaN
# 26                                          EPSG:3577
# 4                                                 NaN
# 41                                          EPSG:3577
# 23                                          EPSG:3577
# 5                                                 NaN
# 1                                                 NaN
# 70                                          EPSG:3577
# 44                                          EPSG:3577
# 72                                          EPSG:3577
# 9                                                 NaN
# 21                                          EPSG:3577
# 10                                                NaN
# 29                                          EPSG:3577
# 11                                                NaN
# 45                                          EPSG:3577
# 22                                          EPSG:3577
# 12                                                NaN
# 8                                                 NaN
# 71                                          EPSG:3577
# 47                                          EPSG:3577
# 40                                                NaN
# 14                                                NaN
# 19                                          EPSG:3577
# 60                                          EPSG:3577
# 57                                                NaN
# 15                                                NaN
# 28                                          EPSG:3577
# 61                                          EPSG:3577
# 58                                                NaN
# 16                                                NaN
# 55                                          EPSG:3577
# 20                                          EPSG:3577
# 59                                                NaN
# 17                                                NaN
# 13                                                NaN
# 49  PROJCS["unnamed",GEOGCS["Unknown datum based u...
# 50  PROJCS["unnamed",GEOGCS["Unknown datum based u...
# 51  PROJCS["unnamed",GEOGCS["Unknown datum based u...
# 52  PROJCS["unnamed",GEOGCS["Unknown datum based u...
# 56                                          EPSG:4326
# 46                                          EPSG:3577
# 62                                          EPSG:3577
#
#                                resolution             tile_size  \
# id
# 36                          [-0.05, 0.05]                  None
# 32  [-0.00027777777778, 0.00027777777778]                  None
# 53                        [-0.001, 0.001]                  None
# 63                              [-25, 25]                  None
# 64                              [-25, 25]                  None
# 67                              [-25, 25]                  None
# 68                              [-25, 25]                  None
# 65                              [-25, 25]                  None
# 66                              [-25, 25]                  None
# 69                              [-25, 25]  [100000.0, 100000.0]
# 42                              [-25, 25]  [100000.0, 100000.0]
# 2                                     NaN                   NaN
# 6                               [-25, 25]  [100000.0, 100000.0]
# 3                                     NaN                   NaN
# 26                              [-25, 25]  [100000.0, 100000.0]
# 4                                     NaN                   NaN
# 41                              [-25, 25]  [100000.0, 100000.0]
# 23                              [-25, 25]  [100000.0, 100000.0]
# 5                                     NaN                   NaN
# 1                                     NaN                   NaN
# 70                              [-25, 25]  [100000.0, 100000.0]
# 44                              [-25, 25]  [100000.0, 100000.0]
# 72                              [-25, 25]  [100000.0, 100000.0]
# 9                                     NaN                   NaN
# 21                              [-25, 25]  [100000.0, 100000.0]
# 10                                    NaN                   NaN
# 29                              [-25, 25]  [100000.0, 100000.0]
# 11                                    NaN                   NaN
# 45                              [-25, 25]  [100000.0, 100000.0]
# 22                              [-25, 25]  [100000.0, 100000.0]
# 12                                    NaN                   NaN
# 8                                     NaN                   NaN
# 71                              [-25, 25]  [100000.0, 100000.0]
# 47                              [-25, 25]  [100000.0, 100000.0]
# 40                                    NaN                   NaN
# 14                                    NaN                   NaN
# 19                              [-25, 25]  [100000.0, 100000.0]
# 60                              [-25, 25]  [100000.0, 100000.0]
# 57                                    NaN                   NaN
# 15                                    NaN                   NaN
# 28                              [-25, 25]  [100000.0, 100000.0]
# 61                              [-25, 25]  [100000.0, 100000.0]
# 58                                    NaN                   NaN
# 16                                    NaN                   NaN
# 55                              [-25, 25]  [100000.0, 100000.0]
# 20                              [-25, 25]  [100000.0, 100000.0]
# 59                                    NaN                   NaN
# 17                                    NaN                   NaN
# 13                                    NaN                   NaN
# 49                                   None                  None
# 50                                   None                  None
# 51                                   None                  None
# 52                                   None                  None
# 56  [-0.00027777777778, 0.00027777777778]                  None
# 46                              [-25, 25]  [100000.0, 100000.0]
# 62                              [-25, 25]  [100000.0, 100000.0]
#
#        spatial_dimensions
# id
# 36  (latitude, longitude)
# 32  (latitude, longitude)
# 53  (latitude, longitude)
# 63                 (y, x)
# 64                 (y, x)
# 67                 (y, x)
# 68                 (y, x)
# 65                 (y, x)
# 66                 (y, x)
# 69                 (y, x)
# 42                 (y, x)
# 2                     NaN
# 6                  (y, x)
# 3                     NaN
# 26                 (y, x)
# 4                     NaN
# 41                 (y, x)
# 23                 (y, x)
# 5                     NaN
# 1                     NaN
# 70                 (y, x)
# 44                 (y, x)
# 72                 (y, x)
# 9                     NaN
# 21                 (y, x)
# 10                    NaN
# 29                 (y, x)
# 11                    NaN
# 45                 (y, x)
# 22                 (y, x)
# 12                    NaN
# 8                     NaN
# 71                 (y, x)
# 47                 (y, x)
# 40                    NaN
# 14                    NaN
# 19                 (y, x)
# 60                 (y, x)
# 57                    NaN
# 15                    NaN
# 28                 (y, x)
# 61                 (y, x)
# 58                    NaN
# 16                    NaN
# 55                 (y, x)
# 20                 (y, x)
# 59                    NaN
# 17                    NaN
# 13                    NaN
# 49                 (y, x)
# 50                 (y, x)
# 51                 (y, x)
# 52                 (y, x)
# 56  (latitude, longitude)
# 46                 (y, x)
# 62                 (y, x)
#
# [56 rows x 29 columns]

# %% [markdown]
# In the list above, we are currently interested in only the column 2. These are the names of products in the datacube. In the code sections below we will examine these products.
#
# You may want to look at the other coumn headings too that give more information about where the data comes from, how it is collected, etc. In particular, the value under the column, **crs** (Coordinate Reference System, also known as Saptial Reference System), tells which geographical area the data applies to. For example, CRS = **EPSG:3527** refers to Australia (all states) alone, whereas **EPSG:4326** refers to the whole world and **EPSG:3857** is the world excluding the polar regions.
#
# If you wish to display specified columns from the returned data, then activate the statement using the function, 'custom_list', in the above code block and disable the other.
#
# **Tip:** The list is long and wide to be displayed on one page. To limit the displayed list to a few lines, click anywhere in the first column (i.e. anywhere below the text saying '**In[nnn]** or **Out[nnn]**')

# %%
dc.list_measurements()
# Out:
#                                                                    aliases  \
# product               measurement
# bom_rainfall_grids    rainfall                                         NaN
# dsm1sv10              elevation                                        NaN
# gamma_ray             rad_air_dose_rate_unfiltered                     NaN
#                       rad_k_equiv_conc_unfiltered                      NaN
#                       rad_u_equiv_conc_unfiltered                      NaN
#                       rad_th_equiv_conc_unfiltered                     NaN
#                       rad_air_dose_rate_filtered                       NaN
#                       rad_k_equiv_conc_filtered                        NaN
#                       rad_u_equiv_conc_filtered                        NaN
#                       rad_th_equiv_conc_filtered                       NaN
#                       rad_ratio_tk                                     NaN
#                       rad_ratio_u2t                                    NaN
#                       rad_ratio_uk                                     NaN
#                       rad_ratio_ut                                     NaN
# high_tide_comp_20p    blue                                             NaN
#                       green                                            NaN
#                       red                                              NaN
#                       nir                                              NaN
#                       swir1                                            NaN
#                       swir2                                            NaN
# high_tide_comp_count  count_observations                               NaN
# item_v2               relative                                         NaN
# item_v2_conf          stddev                                           NaN
# low_tide_comp_20p     blue                                             NaN
#                       green                                            NaN
#                       red                                              NaN
#                       nir                                              NaN
#                       swir1                                            NaN
#                       swir2                                            NaN
# low_tide_comp_count   count_observations                               NaN
# ...                                                                    ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                             NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_nir           NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave     NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_vis           NaN
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6         NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7         NaN
#                       Nadir_Reflectance_Band1                          NaN
#                       Nadir_Reflectance_Band2                          NaN
#                       Nadir_Reflectance_Band3                          NaN
#                       Nadir_Reflectance_Band4                          NaN
#                       Nadir_Reflectance_Band5                          NaN
#                       Nadir_Reflectance_Band6                          NaN
#                       Nadir_Reflectance_Band7                          NaN
# srtm_dem1sv1_0        dem                                              NaN
#                       dem_s                                            NaN
#                       dem_h                                            NaN
# wofs_albers           water                                            NaN
# wofs_modified_albers2 water                                            NaN
#
#                                                                       dtype  \
# product               measurement
# bom_rainfall_grids    rainfall                                      float32
# dsm1sv10              elevation                                     float32
# gamma_ray             rad_air_dose_rate_unfiltered                  float32
#                       rad_k_equiv_conc_unfiltered                   float32
#                       rad_u_equiv_conc_unfiltered                   float32
#                       rad_th_equiv_conc_unfiltered                  float32
#                       rad_air_dose_rate_filtered                    float32
#                       rad_k_equiv_conc_filtered                     float32
#                       rad_u_equiv_conc_filtered                     float32
#                       rad_th_equiv_conc_filtered                    float32
#                       rad_ratio_tk                                  float32
#                       rad_ratio_u2t                                 float32
#                       rad_ratio_uk                                  float32
#                       rad_ratio_ut                                  float32
# high_tide_comp_20p    blue                                          float32
#                       green                                         float32
#                       red                                           float32
#                       nir                                           float32
#                       swir1                                         float32
#                       swir2                                         float32
# high_tide_comp_count  count_observations                              int16
# item_v2               relative                                        int16
# item_v2_conf          stddev                                        float32
# low_tide_comp_20p     blue                                          float32
#                       green                                         float32
#                       red                                           float32
#                       nir                                           float32
#                       swir1                                         float32
#                       swir2                                         float32
# low_tide_comp_count   count_observations                              int16
# ...                                                                     ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                            int16
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_nir          uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave    uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_vis          uint8
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6        uint8
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7        uint8
#                       Nadir_Reflectance_Band1                         int16
#                       Nadir_Reflectance_Band2                         int16
#                       Nadir_Reflectance_Band3                         int16
#                       Nadir_Reflectance_Band4                         int16
#                       Nadir_Reflectance_Band5                         int16
#                       Nadir_Reflectance_Band6                         int16
#                       Nadir_Reflectance_Band7                         int16
# srtm_dem1sv1_0        dem                                           float32
#                       dem_s                                         float32
#                       dem_h                                         float32
# wofs_albers           water                                           uint8
# wofs_modified_albers2 water                                           uint8
#
#                                                                                                      flags_definition  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                                    NaN
# dsm1sv10              elevation                                                                                   NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                                                NaN
#                       rad_k_equiv_conc_unfiltered                                                                 NaN
#                       rad_u_equiv_conc_unfiltered                                                                 NaN
#                       rad_th_equiv_conc_unfiltered                                                                NaN
#                       rad_air_dose_rate_filtered                                                                  NaN
#                       rad_k_equiv_conc_filtered                                                                   NaN
#                       rad_u_equiv_conc_filtered                                                                   NaN
#                       rad_th_equiv_conc_filtered                                                                  NaN
#                       rad_ratio_tk                                                                                NaN
#                       rad_ratio_u2t                                                                               NaN
#                       rad_ratio_uk                                                                                NaN
#                       rad_ratio_ut                                                                                NaN
# high_tide_comp_20p    blue                                                                                        NaN
#                       green                                                                                       NaN
#                       red                                                                                         NaN
#                       nir                                                                                         NaN
#                       swir1                                                                                       NaN
#                       swir2                                                                                       NaN
# high_tide_comp_count  count_observations                                                                          NaN
# item_v2               relative                                                                                    NaN
# item_v2_conf          stddev                                                                                      NaN
# low_tide_comp_20p     blue                                                                                        NaN
#                       green                                                                                       NaN
#                       red                                                                                         NaN
#                       nir                                                                                         NaN
#                       swir1                                                                                       NaN
#                       swir2                                                                                       NaN
# low_tide_comp_count   count_observations                                                                          NaN
# ...                                                                                                               ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                                                                        NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1      {'brdf_albedo_band_mandatory_quality_band1': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2      {'brdf_albedo_band_mandatory_quality_band2': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3      {'brdf_albedo_band_mandatory_quality_band3': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4      {'brdf_albedo_band_mandatory_quality_band4': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5      {'brdf_albedo_band_mandatory_quality_band5': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6      {'brdf_albedo_band_mandatory_quality_band6': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7      {'brdf_albedo_band_mandatory_quality_band7': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_nir        {'brdf_albedo_band_mandatory_quality_band nir'...
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave  {'brdf_albedo_band_mandatory_quality_shortwave...
#                       BRDF_Albedo_Band_Mandatory_Quality_vis        {'brdf_albedo_band_mandatory_quality_vis': {'b...
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1      {'brdf_albedo_band_mandatory_quality_band1': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2      {'brdf_albedo_band_mandatory_quality_band2': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3      {'brdf_albedo_band_mandatory_quality_band3': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4      {'brdf_albedo_band_mandatory_quality_band4': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5      {'brdf_albedo_band_mandatory_quality_band5': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6      {'brdf_albedo_band_mandatory_quality_band6': {...
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7      {'brdf_albedo_band_mandatory_quality_band7': {...
#                       Nadir_Reflectance_Band1                                                                     NaN
#                       Nadir_Reflectance_Band2                                                                     NaN
#                       Nadir_Reflectance_Band3                                                                     NaN
#                       Nadir_Reflectance_Band4                                                                     NaN
#                       Nadir_Reflectance_Band5                                                                     NaN
#                       Nadir_Reflectance_Band6                                                                     NaN
#                       Nadir_Reflectance_Band7                                                                     NaN
# srtm_dem1sv1_0        dem                                                                                         NaN
#                       dem_s                                                                                       NaN
#                       dem_h                                                                                       NaN
# wofs_albers           water                                         {'result': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], ...
# wofs_modified_albers2 water                                         {'dry': {'bits': [7, 6, 5, 4, 3, 1, 0], 'value...
#
#                                                                                                             name  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                          rainfall
# dsm1sv10              elevation                                                                        elevation
# gamma_ray             rad_air_dose_rate_unfiltered                                  rad_air_dose_rate_unfiltered
#                       rad_k_equiv_conc_unfiltered                                    rad_k_equiv_conc_unfiltered
#                       rad_u_equiv_conc_unfiltered                                    rad_u_equiv_conc_unfiltered
#                       rad_th_equiv_conc_unfiltered                                  rad_th_equiv_conc_unfiltered
#                       rad_air_dose_rate_filtered                                      rad_air_dose_rate_filtered
#                       rad_k_equiv_conc_filtered                                        rad_k_equiv_conc_filtered
#                       rad_u_equiv_conc_filtered                                        rad_u_equiv_conc_filtered
#                       rad_th_equiv_conc_filtered                                      rad_th_equiv_conc_filtered
#                       rad_ratio_tk                                                                  rad_ratio_tk
#                       rad_ratio_u2t                                                                rad_ratio_u2t
#                       rad_ratio_uk                                                                  rad_ratio_uk
#                       rad_ratio_ut                                                                  rad_ratio_ut
# high_tide_comp_20p    blue                                                                                  blue
#                       green                                                                                green
#                       red                                                                                    red
#                       nir                                                                                    nir
#                       swir1                                                                                swir1
#                       swir2                                                                                swir2
# high_tide_comp_count  count_observations                                                      count_observations
# item_v2               relative                                                                          relative
# item_v2_conf          stddev                                                                              stddev
# low_tide_comp_20p     blue                                                                                  blue
#                       green                                                                                green
#                       red                                                                                    red
#                       nir                                                                                    nir
#                       swir1                                                                                swir1
#                       swir2                                                                                swir2
# low_tide_comp_count   count_observations                                                      count_observations
# ...                                                                                                          ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                                                  Albedo_WSA_shortwave
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1          BRDF_Albedo_Band_Mandatory_Quality_Band1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2          BRDF_Albedo_Band_Mandatory_Quality_Band2
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3          BRDF_Albedo_Band_Mandatory_Quality_Band3
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4          BRDF_Albedo_Band_Mandatory_Quality_Band4
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5          BRDF_Albedo_Band_Mandatory_Quality_Band5
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6          BRDF_Albedo_Band_Mandatory_Quality_Band6
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7          BRDF_Albedo_Band_Mandatory_Quality_Band7
#                       BRDF_Albedo_Band_Mandatory_Quality_nir              BRDF_Albedo_Band_Mandatory_Quality_nir
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave  BRDF_Albedo_Band_Mandatory_Quality_shortwave
#                       BRDF_Albedo_Band_Mandatory_Quality_vis              BRDF_Albedo_Band_Mandatory_Quality_vis
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1          BRDF_Albedo_Band_Mandatory_Quality_Band1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2          BRDF_Albedo_Band_Mandatory_Quality_Band2
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3          BRDF_Albedo_Band_Mandatory_Quality_Band3
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4          BRDF_Albedo_Band_Mandatory_Quality_Band4
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5          BRDF_Albedo_Band_Mandatory_Quality_Band5
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6          BRDF_Albedo_Band_Mandatory_Quality_Band6
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7          BRDF_Albedo_Band_Mandatory_Quality_Band7
#                       Nadir_Reflectance_Band1                                            Nadir_Reflectance_Band1
#                       Nadir_Reflectance_Band2                                            Nadir_Reflectance_Band2
#                       Nadir_Reflectance_Band3                                            Nadir_Reflectance_Band3
#                       Nadir_Reflectance_Band4                                            Nadir_Reflectance_Band4
#                       Nadir_Reflectance_Band5                                            Nadir_Reflectance_Band5
#                       Nadir_Reflectance_Band6                                            Nadir_Reflectance_Band6
#                       Nadir_Reflectance_Band7                                            Nadir_Reflectance_Band7
# srtm_dem1sv1_0        dem                                                                                    dem
#                       dem_s                                                                                dem_s
#                       dem_h                                                                                dem_h
# wofs_albers           water                                                                                water
# wofs_modified_albers2 water                                                                                water
#
#                                                                                                       nodata  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                          -999
# dsm1sv10              elevation                                                                          NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                                    -99999
#                       rad_k_equiv_conc_unfiltered                                                     -99999
#                       rad_u_equiv_conc_unfiltered                                                     -99999
#                       rad_th_equiv_conc_unfiltered                                                    -99999
#                       rad_air_dose_rate_filtered                                                      -99999
#                       rad_k_equiv_conc_filtered                                                       -99999
#                       rad_u_equiv_conc_filtered                                                       -99999
#                       rad_th_equiv_conc_filtered                                                      -99999
#                       rad_ratio_tk                                                                    -99999
#                       rad_ratio_u2t                                                                   -99999
#                       rad_ratio_uk                                                                    -99999
#                       rad_ratio_ut                                                                    -99999
# high_tide_comp_20p    blue                                                                              -999
#                       green                                                                             -999
#                       red                                                                               -999
#                       nir                                                                               -999
#                       swir1                                                                             -999
#                       swir2                                                                             -999
# high_tide_comp_count  count_observations                                                                   0
# item_v2               relative                                                                             0
# item_v2_conf          stddev                                                                           -6666
# low_tide_comp_20p     blue                                                                              -999
#                       green                                                                             -999
#                       red                                                                               -999
#                       nir                                                                               -999
#                       swir1                                                                             -999
#                       swir2                                                                             -999
# low_tide_comp_count   count_observations                                                                   0
# ...                                                                                                      ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                                                             32767
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_nir                                             255
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave                                       255
#                       BRDF_Albedo_Band_Mandatory_Quality_vis                                             255
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                                           255
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                                           255
#                       Nadir_Reflectance_Band1                                                          32767
#                       Nadir_Reflectance_Band2                                                          32767
#                       Nadir_Reflectance_Band3                                                          32767
#                       Nadir_Reflectance_Band4                                                          32767
#                       Nadir_Reflectance_Band5                                                          32767
#                       Nadir_Reflectance_Band6                                                          32767
#                       Nadir_Reflectance_Band7                                                          32767
# srtm_dem1sv1_0        dem                                           -340282350000000000000000000000000000000
#                       dem_s                                         -340282350000000000000000000000000000000
#                       dem_h                                         -340282350000000000000000000000000000000
# wofs_albers           water                                                                                1
# wofs_modified_albers2 water                                                                                1
#
#                                                                                                   spectral_definition  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                                    NaN
# dsm1sv10              elevation                                                                                   NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                                                NaN
#                       rad_k_equiv_conc_unfiltered                                                                 NaN
#                       rad_u_equiv_conc_unfiltered                                                                 NaN
#                       rad_th_equiv_conc_unfiltered                                                                NaN
#                       rad_air_dose_rate_filtered                                                                  NaN
#                       rad_k_equiv_conc_filtered                                                                   NaN
#                       rad_u_equiv_conc_filtered                                                                   NaN
#                       rad_th_equiv_conc_filtered                                                                  NaN
#                       rad_ratio_tk                                                                                NaN
#                       rad_ratio_u2t                                                                               NaN
#                       rad_ratio_uk                                                                                NaN
#                       rad_ratio_ut                                                                                NaN
# high_tide_comp_20p    blue                                                                                        NaN
#                       green                                                                                       NaN
#                       red                                                                                         NaN
#                       nir                                                                                         NaN
#                       swir1                                                                                       NaN
#                       swir2                                                                                       NaN
# high_tide_comp_count  count_observations                                                                          NaN
# item_v2               relative                                                                                    NaN
# item_v2_conf          stddev                                                                                      NaN
# low_tide_comp_20p     blue                                                                                        NaN
#                       green                                                                                       NaN
#                       red                                                                                         NaN
#                       nir                                                                                         NaN
#                       swir1                                                                                       NaN
#                       swir2                                                                                       NaN
# low_tide_comp_count   count_observations                                                                          NaN
# ...                                                                                                               ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                                                                        NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_nir                                                      NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave                                                NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_vis                                                      NaN
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                                                    NaN
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                                                    NaN
#                       Nadir_Reflectance_Band1                       {'response': [0.000527, 0.0, 0.000813, 7.3e-05...
#                       Nadir_Reflectance_Band2                       {'response': [0.000614, 0.000153, 0.000276, 0....
#                       Nadir_Reflectance_Band3                       {'response': [0.000632, 0.000158, 0.000569, 0....
#                       Nadir_Reflectance_Band4                       {'response': [0.000626, 0.000644, 9.1e-05, 3.3...
#                       Nadir_Reflectance_Band5                       {'response': [4e-05, 0.00012, 0.00016, 0.00019...
#                       Nadir_Reflectance_Band6                       {'response': [7e-06, 1e-06, 2e-06, 0.0, 5e-06,...
#                       Nadir_Reflectance_Band7                       {'response': [1e-06, 1e-06, 1e-06, 0.0, 1e-06,...
# srtm_dem1sv1_0        dem                                                                                         NaN
#                       dem_s                                                                                       NaN
#                       dem_h                                                                                       NaN
# wofs_albers           water                                                                                       NaN
# wofs_modified_albers2 water                                                                                       NaN
#
#                                                                           units
# product               measurement
# bom_rainfall_grids    rainfall                                               mm
# dsm1sv10              elevation                                           metre
# gamma_ray             rad_air_dose_rate_unfiltered                         nG/h
#                       rad_k_equiv_conc_unfiltered                            %K
#                       rad_u_equiv_conc_unfiltered                           ppm
#                       rad_th_equiv_conc_unfiltered                          ppm
#                       rad_air_dose_rate_filtered                           nG/h
#                       rad_k_equiv_conc_filtered                              %K
#                       rad_u_equiv_conc_filtered                             ppm
#                       rad_th_equiv_conc_filtered                            ppm
#                       rad_ratio_tk                                      ppm / %
#                       rad_ratio_u2t                                 ppm^2 / ppm
#                       rad_ratio_uk                                      ppm / %
#                       rad_ratio_ut                                    ppm / ppm
# high_tide_comp_20p    blue                                                    1
#                       green                                                   1
#                       red                                                     1
#                       nir                                                     1
#                       swir1                                                   1
#                       swir2                                                   1
# high_tide_comp_count  count_observations                                      1
# item_v2               relative                                              0.1
# item_v2_conf          stddev                                                  1
# low_tide_comp_20p     blue                                                    1
#                       green                                                   1
#                       red                                                     1
#                       nir                                                     1
#                       swir1                                                   1
#                       swir2                                                   1
# low_tide_comp_count   count_observations                                      1
# ...                                                                         ...
# modis_mcd43a3_tile    Albedo_WSA_shortwave                                    1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band1                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                1
#                       BRDF_Albedo_Band_Mandatory_Quality_nir                  1
#                       BRDF_Albedo_Band_Mandatory_Quality_shortwave            1
#                       BRDF_Albedo_Band_Mandatory_Quality_vis                  1
# modis_mcd43a4_tile    BRDF_Albedo_Band_Mandatory_Quality_Band1                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band2                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band3                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band4                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band5                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band6                1
#                       BRDF_Albedo_Band_Mandatory_Quality_Band7                1
#                       Nadir_Reflectance_Band1                                 1
#                       Nadir_Reflectance_Band2                                 1
#                       Nadir_Reflectance_Band3                                 1
#                       Nadir_Reflectance_Band4                                 1
#                       Nadir_Reflectance_Band5                                 1
#                       Nadir_Reflectance_Band6                                 1
#                       Nadir_Reflectance_Band7                                 1
# srtm_dem1sv1_0        dem                                                 metre
#                       dem_s                                               metre
#                       dem_h                                               metre
# wofs_albers           water                                                   1
# wofs_modified_albers2 water                                                   1
#
# [259 rows x 7 columns]

# %% [markdown]
# As in the case of **list_products**, this returns the details corresponding to each product. The products are listed in column 1 and the different measurements in column 2. There are more columns too.

# %% [markdown]
# ## Let us investigate a specified product's dataset in more detail
#
# In the code block below we create an object, **dataset**, for a desired product from the above list. **Tip:** You can replace the product name in brackets with any other to examine its data.

# %%
# Choose a dataset to investigate
dataset = dc.index.products.get_by_name('modis_mcd43a4_tile')

# %% [markdown]
# In the code above, we are creating the **dataset** object by calling three classes and one method hierarchically.
#
# > Class object **dc** -> class **index** -> class **products** -> method **get_by_name**
#
# The returned class object, **dataset**, can be used to display details pertaining to the product.

# %%
# Get some information about the data itself
raw = dataset.measurements
formatted_data = pandas.DataFrame.from_dict(raw)

# Uncomment one of the two statements below to display the data as raw (dict) or formatted
#print(raw)   # Display the raw data in dictionary format
#print(formatted_data)  # Print it as formatted

# Function to display it in more human readable format
for key in raw:
    print_it(key,raw[key])
    pass

# Or, see it displayed in the default format
#dataset.measurements
# Out:
# Brdf_Albedo_Band_Mandatory_Quality_Band1:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band1
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band1:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 1 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band2:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band2
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band2:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 2 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band3:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band3
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band3:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 3 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band4:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band4
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band4:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 4 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band5:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band5
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band5:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 5 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band6:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band6
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band6:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 6 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value
#
# Brdf_Albedo_Band_Mandatory_Quality_Band7:
#     Name: BRDF_Albedo_Band_Mandatory_Quality_Band7
#
#     Dtype: uint8
#
#     Units: 1
#
#     Nodata: 255
#
# Flags_Definition:
# Brdf_Albedo_Band_Mandatory_Quality_Band7:
#     Bits: [0, 1, 2, 3, 4, 5, 6, 7]
#
# Values:
#     0: best
#
#     1: good
#
#     255: fill
#
#     Description: BRDF Albedo Mandatory Quality for band 7 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill
, 3600.0, 3650.0, 3700.0, 3750.0, 3800.0, 3850.0, 3900.0, 3950.0, 4000.0, 4050.0, 4100.0, 4150.0, 4200.0, 4250.0, 4300.0, 4350.0, 4400.0, 4450.0, 4500.0, 4550.0, 4600.0, 4650.0, 4700.0, 4750.0, 4800.0, 4850.0, 4900.0, 4950.0, 5000.0, 5050.0, 5100.0, 5150.0, 5200.0, 5250.0, 5300.0, 5350.0, 5400.0]

# %% [markdown]
# Here, we are getting the measurements for the product specified in the code above. The data is a dictionary list which can be printed as such, in which case it will be meaningful to an AI robot, or formatted for humans. The **pandas DataFrame**, described earlier, re-formats the data into rows and columns. You can try both by commenting/uncommenting the two 'print' statements in the code above.
#
# Alternatively, using a small Python function, 'print_it', specifically written for this application, it can be formatted in an even more meaningful way. You can change this function to suit your taste, but the pandas format cannot be changed.

# %%
# Get some basic metadata
raw = dataset.metadata_doc
formatted_data = pandas.DataFrame.from_dict(raw)
#print(raw)   # Display the raw data in dictionary format
print(formatted_data)  # Print it as formatted
# Out:
#                  format instrument    platform product_type
# code                NaN        NaN  AQUA_TERRA      MCD43A4
# name  HDF4_EOS:EOS_GRID      MODIS         NaN      MCD43A4

# %% [markdown]
# Here, we are getting the metadata for the product specified in the code above. A method from **pandas DataFrame** re-formats the data into rows and columns. You can try both by commenting/uncommenting the two 'print' statements in teh code above.

# %%
raw = dataset.definition
#formatted_data = pandas.DataFrame.from_dict(dataset.definition)
#print(formatted_data)  # Print it as formatted

for key in raw:
    print_it(key,raw[key])
    pass

# Or, see it displayed in the default format
#dataset.definition
# Out:
#     Name: modis_mcd43a4_tile
#
# Storage:
#     Crs: PROJCS["unnamed",GEOGCS["Unknown datum based upon the custom spheroid",DATUM["Not specified (based on custom spheroid)",SPHEROID["Custom spheroid",6371007.181,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433]],PROJECTION["Sinusoidal"],PARAMETER["longitude_of_center",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["Meter",1]]
#
#
# Metadata:
# Format:
#     Name: HDF4_EOS:EOS_GRID
#
# Platform:
#     Code: AQUA_TERRA
#
# Instrument:
#     Name: MODIS
#
#     Product_Type: MCD43A4
#
#     Description: MODIS 500 metre MCD43A4 Collection 006
#
#     Measurements: [{'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band1', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band1': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 1 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band2', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band2': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 2 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band3', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band3': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 3 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band4', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band4': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 4 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band5', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band5': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 5 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band6', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band6': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 6 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'BRDF_Albedo_Band_Mandatory_Quality_Band7', 'dtype': 'uint8', 'units': '1', 'nodata': 255, 'flags_definition': {'brdf_albedo_band_mandatory_quality_band7': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'best', '1': 'good', '255': 'fill'}, 'description': 'BRDF Albedo Mandatory Quality for band 7 0 = processed, good quality (full BRDF) 1 = processed, see other QA (magnitude BRDF inversions) 255 = Fill value'}}}, {'name': 'Nadir_Reflectance_Band1', 'dtype': 'int16', 'units': '1', 'nodata': 32767, 'spectral_definition': {'response': [0.000527, 0.0, 0.000813, 7.3e-05, 0.000463, 0.000475, 0.000154, 7.6e-05, 0.000103, 9.4e-05, 1e-05, 6.1e-05, 7.4e-05, 5.1e-05, 3.9e-05, 2.5e-05, 1.4e-05, 4e-06, 1.6e-05, 4e-06, 1.5e-05, 1.4e-05, 3e-05, 4e-05, 3.4e-05, 3e-05, 4e-05, 0.00011, 0.00043, 0.00109, 0.00602, 0.01, 0.02764, 0.17854, 0.40707, 0.70887, 0.76935, 0.77862, 0.78443, 0.78969, 0.79697, 0.81246, 0.82465, 0.84857, 0.87203, 0.91178, 0.92625, 0.97203, 0.99346, 1.0, 0.96256, 0.8093, 0.7211, 0.53771, 0.38381, 0.17267, 0.08932, 0.02994, 0.01408, 0.01, 0.00205, 0.00079, 0.00045, 0.00022, 0.0001, 4e-05, 3e-05, 1e-05, 1e-05, 0.0, 1.9e-05, 5e-06, 5e-05, 2.9e-05, 4.1e-05, 0.0, 2.3e-05, 0.00016, 1.5e-05, 1.7e-05, 1.9e-05, 0.000183, 0.000323, 0.000479, 0.000349, 0.000165, 1.5e-05, 3.8e-05, 6.7e-05, 2.9e-05, 5.3e-05, 8e-06, 2.2e-05, 6.7e-05, 4.4e-05, 0.000126, 6.3e-05, 2.2e-05, 4.1e-05, 4.9e-05, 5.2e ...
#
#     Metadata_Type: eo

# %% [markdown]
# Here, we are getting the definition for the product specified in the code above. The data is a dictionary list as in the case of metadata. The **pandas DataFrame** is unusable in this case due to some [unknown] difference in format. Hence, we must use the python 'print_it' function given in the code block above.

# %% [markdown]
# **The code blocks above, and their descriptions, should let you examine any product in the datacube. Enjoy! **
